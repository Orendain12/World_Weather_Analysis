# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 616

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=35fcfce3e8fd2d3f9f49de9e140f0ef9

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description'] 
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
                        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belmonte
# Processing Record 2 of Set 1 | udachnyy
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | muhos
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | baruun-urt
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | mumford
# Processing Record 18 of Set 1 | wawa
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 1 | ingham
# Processing Record 24 of Set 1 | zhob
# Processing Record 25 of Set 1 | carutapera
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | entre rios
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | caluquembe
# Processing Record 33 of Set 1 | umm kaddadah
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | colares
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | jiblah
# Processing Record 39 of Set 1 | keshan
# City not found. Skipping...
# Processing Record 40 of Set 1 | melbu
# Processing Record 41 of Set 1 | sao jose da coroa grande
# Processing Record 42 of Set 1 | paamiut
# Processing Record 43 of Set 1 | yulara
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | zhigansk
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | tambo
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | paveh
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | waipawa
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | cascavel
# Processing Record 10 of Set 2 | coquimbo
# Processing Record 11 of Set 2 | tuburan
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | superior
# Processing Record 14 of Set 2 | cairns
# Processing Record 15 of Set 2 | porosozero
# Processing Record 16 of Set 2 | terney
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | kununurra
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | fort saint james
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | san antonio
# Processing Record 23 of Set 2 | gamba
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | warwick
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | abu samrah
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | nagyatad
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | qui nhon
# Processing Record 34 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | havelock
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | arroyo
# Processing Record 39 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 2 | ormstown
# Processing Record 41 of Set 2 | puerto suarez
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | komsomolskiy
# Processing Record 45 of Set 2 | ambulu
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | ampanihy
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | ushtobe
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | mayo
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 3 | berlevag
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | gorin
# Processing Record 8 of Set 3 | nhulunbuy
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | gorontalo
# Processing Record 11 of Set 3 | manaure
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | raudeberg
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | dunedin
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | norman wells
# Processing Record 19 of Set 3 | mogok
# Processing Record 20 of Set 3 | kitob
# Processing Record 21 of Set 3 | maunabo
# Processing Record 22 of Set 3 | yantal
# Processing Record 23 of Set 3 | vorotynets
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | hamburg
# Processing Record 27 of Set 3 | adana
# Processing Record 28 of Set 3 | grindavik
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | aykhal
# Processing Record 31 of Set 3 | lieksa
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | sobolevo
# Processing Record 34 of Set 3 | galle
# Processing Record 35 of Set 3 | chapais
# Processing Record 36 of Set 3 | davila
# Processing Record 37 of Set 3 | goderich
# Processing Record 38 of Set 3 | najran
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | kendari
# Processing Record 41 of Set 3 | ballina
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | srandakan
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | makushino
# Processing Record 46 of Set 3 | presidencia roque saenz pena
# Processing Record 47 of Set 3 | sembe
# Processing Record 48 of Set 3 | wilmington
# Processing Record 49 of Set 3 | namibe
# Processing Record 50 of Set 3 | dikson
# Processing Record 1 of Set 4 | hervey bay
# Processing Record 2 of Set 4 | inhambane
# Processing Record 3 of Set 4 | callaway
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | san quintin
# Processing Record 6 of Set 4 | boden
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | san isidro
# Processing Record 9 of Set 4 | necochea
# Processing Record 10 of Set 4 | dolinsk
# Processing Record 11 of Set 4 | margate
# Processing Record 12 of Set 4 | kuching
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | lasa
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | kenai
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | ngunguru
# Processing Record 21 of Set 4 | areka
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | neiafu
# Processing Record 24 of Set 4 | palmares do sul
# Processing Record 25 of Set 4 | mumbwa
# Processing Record 26 of Set 4 | tazmalt
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | choma
# Processing Record 30 of Set 4 | kitgum
# Processing Record 31 of Set 4 | arklow
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | pangkalanbuun
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | samarskoye
# Processing Record 39 of Set 4 | dale
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | muravlenko
# Processing Record 44 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 4 | kelo
# Processing Record 46 of Set 4 | kutum
# Processing Record 47 of Set 4 | marrakesh
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | vanimo
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | ahuimanu
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | khandagayty
# Processing Record 4 of Set 5 | evensk
# Processing Record 5 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 5 | general pico
# Processing Record 7 of Set 5 | tessalit
# Processing Record 8 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 9 of Set 5 | las vegas
# Processing Record 10 of Set 5 | verkhnyaya sinyachikha
# Processing Record 11 of Set 5 | alice
# Processing Record 12 of Set 5 | sistranda
# Processing Record 13 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | basco
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | aparecida do taboado
# Processing Record 18 of Set 5 | deming
# Processing Record 19 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 5 | tautira
# Processing Record 21 of Set 5 | novyy urengoy
# Processing Record 22 of Set 5 | srednekolymsk
# Processing Record 23 of Set 5 | acurenam
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | avera
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 5 | redmond
# Processing Record 30 of Set 5 | vilyuysk
# Processing Record 31 of Set 5 | truro
# Processing Record 32 of Set 5 | cabra
# Processing Record 33 of Set 5 | moorhead
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | rio gallegos
# Processing Record 36 of Set 5 | nago
# Processing Record 37 of Set 5 | simonesti
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | khorixas
# Processing Record 41 of Set 5 | saint-joseph
# Processing Record 42 of Set 5 | mandalgovi
# Processing Record 43 of Set 5 | labuhan
# Processing Record 44 of Set 5 | amuntai
# Processing Record 45 of Set 5 | cap malheureux
# Processing Record 46 of Set 5 | pontes e lacerda
# Processing Record 47 of Set 5 | lanzhou
# Processing Record 48 of Set 5 | campbellsville
# Processing Record 49 of Set 5 | caravelas
# Processing Record 50 of Set 5 | tommot
# Processing Record 1 of Set 6 | kolosovka
# Processing Record 2 of Set 6 | bam
# Processing Record 3 of Set 6 | caiaponia
# Processing Record 4 of Set 6 | chara
# Processing Record 5 of Set 6 | deputatskiy
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | kasongo-lunda
# Processing Record 8 of Set 6 | sogdiondon
# City not found. Skipping...
# Processing Record 9 of Set 6 | simpang
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | lagoa
# Processing Record 12 of Set 6 | agapovka
# Processing Record 13 of Set 6 | lima
# Processing Record 14 of Set 6 | saint-philippe
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | santiago de cao
# Processing Record 17 of Set 6 | juegang
# Processing Record 18 of Set 6 | chicama
# Processing Record 19 of Set 6 | ancud
# Processing Record 20 of Set 6 | coos bay
# Processing Record 21 of Set 6 | mbandaka
# Processing Record 22 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 6 | asfi
# Processing Record 24 of Set 6 | urumqi
# Processing Record 25 of Set 6 | umm lajj
# Processing Record 26 of Set 6 | kieta
# Processing Record 27 of Set 6 | dudinka
# Processing Record 28 of Set 6 | hays
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | nangwa
# Processing Record 31 of Set 6 | dolores
# Processing Record 32 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 6 | harbour breton
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | methoni
# Processing Record 36 of Set 6 | solnechnyy
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | laurinburg
# Processing Record 39 of Set 6 | turukhansk
# Processing Record 40 of Set 6 | warmbad
# Processing Record 41 of Set 6 | dakoro
# Processing Record 42 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 6 | port augusta
# Processing Record 44 of Set 6 | kijini
# Processing Record 45 of Set 6 | manavalakurichi
# Processing Record 46 of Set 6 | lianran
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | handan
# Processing Record 49 of Set 6 | bereda
# Processing Record 50 of Set 6 | mazatlan
# Processing Record 1 of Set 7 | chumikan
# Processing Record 2 of Set 7 | vao
# Processing Record 3 of Set 7 | maiduguri
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | sambava
# Processing Record 6 of Set 7 | marigot
# Processing Record 7 of Set 7 | tigil
# Processing Record 8 of Set 7 | pingliang
# Processing Record 9 of Set 7 | brae
# Processing Record 10 of Set 7 | kalmunai
# Processing Record 11 of Set 7 | alofi
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | chokurdakh
# Processing Record 14 of Set 7 | valdosta
# Processing Record 15 of Set 7 | ugoofaaru
# Processing Record 16 of Set 7 | marawi
# Processing Record 17 of Set 7 | santa rosa
# Processing Record 18 of Set 7 | imbituba
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | ketchikan
# Processing Record 21 of Set 7 | rudraprayag
# Processing Record 22 of Set 7 | elk city
# Processing Record 23 of Set 7 | bambous virieux
# Processing Record 24 of Set 7 | pemba
# Processing Record 25 of Set 7 | cockburn town
# Processing Record 26 of Set 7 | high level
# Processing Record 27 of Set 7 | buchanan
# Processing Record 28 of Set 7 | vila velha
# Processing Record 29 of Set 7 | rovaniemi
# Processing Record 30 of Set 7 | skjervoy
# Processing Record 31 of Set 7 | panguna
# Processing Record 32 of Set 7 | aripuana
# Processing Record 33 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 34 of Set 7 | ulagan
# Processing Record 35 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 36 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 37 of Set 7 | portsmouth
# Processing Record 38 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | kihei
# Processing Record 41 of Set 7 | upplands-vasby
# City not found. Skipping...
# Processing Record 42 of Set 7 | ostrovnoy
# Processing Record 43 of Set 7 | adrar
# Processing Record 44 of Set 7 | devonport
# Processing Record 45 of Set 7 | maceio
# Processing Record 46 of Set 7 | belle fourche
# Processing Record 47 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 7 | upata
# Processing Record 49 of Set 7 | sawakin
# Processing Record 50 of Set 7 | hami
# Processing Record 1 of Set 8 | tosya
# Processing Record 2 of Set 8 | hakkari
# Processing Record 3 of Set 8 | murgab
# Processing Record 4 of Set 8 | kurchum
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | talaya
# Processing Record 9 of Set 8 | bethel
# Processing Record 10 of Set 8 | pacific grove
# Processing Record 11 of Set 8 | inndyr
# Processing Record 12 of Set 8 | saurimo
# Processing Record 13 of Set 8 | beitbridge
# Processing Record 14 of Set 8 | demyansk
# Processing Record 15 of Set 8 | flinders
# Processing Record 16 of Set 8 | pombal
# Processing Record 17 of Set 8 | husavik
# Processing Record 18 of Set 8 | brits
# Processing Record 19 of Set 8 | ahipara
# Processing Record 20 of Set 8 | putyatino
# Processing Record 21 of Set 8 | susanino
# Processing Record 22 of Set 8 | tagusao
# Processing Record 23 of Set 8 | kaitangata
# Processing Record 24 of Set 8 | chuy
# Processing Record 25 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 8 | torres
# Processing Record 27 of Set 8 | krasnoselkup
# Processing Record 28 of Set 8 | fatehpur
# Processing Record 29 of Set 8 | college
# Processing Record 30 of Set 8 | vikulovo
# Processing Record 31 of Set 8 | matara
# Processing Record 32 of Set 8 | tevriz
# Processing Record 33 of Set 8 | ponta do sol
# Processing Record 34 of Set 8 | pujehun
# Processing Record 35 of Set 8 | faanui
# Processing Record 36 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 8 | alta floresta
# Processing Record 38 of Set 8 | guerrero negro
# Processing Record 39 of Set 8 | sao filipe
# Processing Record 40 of Set 8 | jiaojiang
# Processing Record 41 of Set 8 | pevek
# Processing Record 42 of Set 8 | chegdomyn
# Processing Record 43 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 44 of Set 8 | gboko
# Processing Record 45 of Set 8 | bara
# Processing Record 46 of Set 8 | asau
# Processing Record 47 of Set 8 | comodoro rivadavia
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | sabha
# Processing Record 50 of Set 8 | mogadishu
# Processing Record 1 of Set 9 | manica
# Processing Record 2 of Set 9 | fort nelson
# Processing Record 3 of Set 9 | atar
# Processing Record 4 of Set 9 | nouadhibou
# Processing Record 5 of Set 9 | hermiston
# Processing Record 6 of Set 9 | olafsvik
# Processing Record 7 of Set 9 | tabou
# Processing Record 8 of Set 9 | sayabec
# City not found. Skipping...
# Processing Record 9 of Set 9 | itaquyry
# Processing Record 10 of Set 9 | alekseyevsk
# Processing Record 11 of Set 9 | chokwe
# Processing Record 12 of Set 9 | klaksvik
# Processing Record 13 of Set 9 | bubaque
# Processing Record 14 of Set 9 | north bend
# Processing Record 15 of Set 9 | buala
# Processing Record 16 of Set 9 | pangnirtung
# Processing Record 17 of Set 9 | lahij
# Processing Record 18 of Set 9 | saint-pierre
# Processing Record 19 of Set 9 | palmer
# Processing Record 20 of Set 9 | ulladulla
# Processing Record 21 of Set 9 | vila do maio
# Processing Record 22 of Set 9 | hovd
# Processing Record 23 of Set 9 | thinadhoo
# Processing Record 24 of Set 9 | lebedyn
# Processing Record 25 of Set 9 | omboue
# Processing Record 26 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 9 | san juan
# Processing Record 28 of Set 9 | bukachacha
# Processing Record 29 of Set 9 | mount isa
# Processing Record 30 of Set 9 | fayaoue
# Processing Record 31 of Set 9 | port blair
# Processing Record 32 of Set 9 | kurumkan
# Processing Record 33 of Set 9 | san pedro
# Processing Record 34 of Set 9 | ruidoso
# Processing Record 35 of Set 9 | isangel
# Processing Record 36 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 9 | homer
# Processing Record 38 of Set 9 | vilhena
# Processing Record 39 of Set 9 | mitsamiouli
# Processing Record 40 of Set 9 | callaguip
# Processing Record 41 of Set 9 | dutlwe
# Processing Record 42 of Set 9 | shelburne
# Processing Record 43 of Set 9 | imeni poliny osipenko
# Processing Record 44 of Set 9 | arrecife
# Processing Record 45 of Set 9 | verkhnevilyuysk
# Processing Record 46 of Set 9 | sinnamary
# Processing Record 47 of Set 9 | coronel mariduena
# City not found. Skipping...
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | manta
# Processing Record 50 of Set 9 | corning
# Processing Record 1 of Set 10 | manicore
# Processing Record 2 of Set 10 | mbanza-ngungu
# Processing Record 3 of Set 10 | maniitsoq
# Processing Record 4 of Set 10 | arlit
# Processing Record 5 of Set 10 | shimoda
# Processing Record 6 of Set 10 | tisul
# Processing Record 7 of Set 10 | awjilah
# Processing Record 8 of Set 10 | bonthe
# Processing Record 9 of Set 10 | cidreira
# Processing Record 10 of Set 10 | sur
# Processing Record 11 of Set 10 | vila franca do campo
# Processing Record 12 of Set 10 | katsuura
# Processing Record 13 of Set 10 | mattru
# Processing Record 14 of Set 10 | rey bouba
# Processing Record 15 of Set 10 | karratha
# Processing Record 16 of Set 10 | bethanien
# Processing Record 17 of Set 10 | tomatlan
# Processing Record 18 of Set 10 | san cristobal
# Processing Record 19 of Set 10 | trairi
# Processing Record 20 of Set 10 | bengkulu
# Processing Record 21 of Set 10 | bol
# Processing Record 22 of Set 10 | ambikapur
# Processing Record 23 of Set 10 | lopatyn
# Processing Record 24 of Set 10 | harsum
# Processing Record 25 of Set 10 | okato
# Processing Record 26 of Set 10 | ler
# Processing Record 27 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 10 | araguaina
# Processing Record 29 of Set 10 | puerto ayacucho
# Processing Record 30 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | crestview
# Processing Record 32 of Set 10 | kathu
# Processing Record 33 of Set 10 | waitara
# Processing Record 34 of Set 10 | prince rupert
# Processing Record 35 of Set 10 | tarakan
# Processing Record 36 of Set 10 | kholm
# Processing Record 37 of Set 10 | oranjemund
# Processing Record 38 of Set 10 | taoudenni
# Processing Record 39 of Set 10 | abadan
# Processing Record 40 of Set 10 | san javier
# Processing Record 41 of Set 10 | wakkanai
# Processing Record 42 of Set 10 | carhuamayo
# Processing Record 43 of Set 10 | kaohsiung
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | los llanos de aridane
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | tura
# Processing Record 48 of Set 10 | corato
# Processing Record 49 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 10 | pag
# Processing Record 1 of Set 11 | kipini
# Processing Record 2 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 11 | draguignan
# Processing Record 4 of Set 11 | khandyga
# Processing Record 5 of Set 11 | kysyl-syr
# Processing Record 6 of Set 11 | rio grande
# Processing Record 7 of Set 11 | pleasanton
# Processing Record 8 of Set 11 | cabedelo
# Processing Record 9 of Set 11 | sliac
# City not found. Skipping...
# Processing Record 10 of Set 11 | biak
# Processing Record 11 of Set 11 | dzaoudzi
# Processing Record 12 of Set 11 | jalu
# Processing Record 13 of Set 11 | cuiluan
# Processing Record 14 of Set 11 | salina cruz
# Processing Record 15 of Set 11 | the valley
# Processing Record 16 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 11 | bow island
# Processing Record 18 of Set 11 | ciudad bolivar
# Processing Record 19 of Set 11 | vostok
# Processing Record 20 of Set 11 | arica
# Processing Record 21 of Set 11 | boa vista
# Processing Record 22 of Set 11 | saint george
# Processing Record 23 of Set 11 | jalalabad
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | santiago del estero
# Processing Record 26 of Set 11 | joensuu
# Processing Record 27 of Set 11 | metro
# Processing Record 28 of Set 11 | pundaguitan
# Processing Record 29 of Set 11 | mama
# Processing Record 30 of Set 11 | pemberton
# Processing Record 31 of Set 11 | saint-francois
# Processing Record 32 of Set 11 | santa cruz
# Processing Record 33 of Set 11 | kumluca
# Processing Record 34 of Set 11 | tucuman
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | penzance
# Processing Record 37 of Set 11 | padang
# Processing Record 38 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 11 | gien
# Processing Record 40 of Set 11 | buraydah
# Processing Record 41 of Set 11 | lahaina
# Processing Record 42 of Set 11 | khromtau
# Processing Record 43 of Set 11 | tuskegee
# Processing Record 44 of Set 11 | inverell
# Processing Record 45 of Set 11 | bodden town
# Processing Record 46 of Set 11 | lamar
# Processing Record 47 of Set 11 | camana
# Processing Record 48 of Set 11 | sulphur springs
# Processing Record 49 of Set 11 | acajutla
# Processing Record 50 of Set 11 | petropavlovka
# Processing Record 1 of Set 12 | petatlan
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | maua
# Processing Record 4 of Set 12 | abomsa
# Processing Record 5 of Set 12 | kavaratti
# Processing Record 6 of Set 12 | anadyr
# Processing Record 7 of Set 12 | nabire
# Processing Record 8 of Set 12 | atherton
# Processing Record 9 of Set 12 | nemuro
# Processing Record 10 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 11 of Set 12 | mgandu
# Processing Record 12 of Set 12 | fremont
# Processing Record 13 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 12 | sao felix do xingu
# Processing Record 15 of Set 12 | merauke
# Processing Record 16 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 12 | praia da vitoria
# Processing Record 18 of Set 12 | varkkallai
# Processing Record 19 of Set 12 | akyab
# Processing Record 20 of Set 12 | benemerito de las americas
# Processing Record 21 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 12 | u thong
# Processing Record 23 of Set 12 | khasan
# Processing Record 24 of Set 12 | iralaya
# Processing Record 25 of Set 12 | tiarei
# Processing Record 26 of Set 12 | vanavara
# Processing Record 27 of Set 12 | toyooka
# Processing Record 28 of Set 12 | dhanwar
# Processing Record 29 of Set 12 | iwanai
# Processing Record 30 of Set 12 | yar-sale
# Processing Record 31 of Set 12 | fallon
# Processing Record 32 of Set 12 | jaunjelgava
# Processing Record 33 of Set 12 | portland
# Processing Record 34 of Set 12 | shihezi
# Processing Record 35 of Set 12 | kuryk
# Processing Record 36 of Set 12 | loa janan
# Processing Record 37 of Set 12 | pascagoula
# Processing Record 38 of Set 12 | sangar
# Processing Record 39 of Set 12 | santa maria do para
# Processing Record 40 of Set 12 | saint-lo
# Processing Record 41 of Set 12 | gornopravdinsk
# Processing Record 42 of Set 12 | faya
# Processing Record 43 of Set 12 | pacifica
# Processing Record 44 of Set 12 | mackay
# Processing Record 45 of Set 12 | klerksdorp
# Processing Record 46 of Set 12 | lukulu
# Processing Record 47 of Set 12 | selimpasa
# Processing Record 48 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 49 of Set 12 | verkh-usugli
# Processing Record 50 of Set 12 | cascais
# Processing Record 1 of Set 13 | hambantota
# Processing Record 2 of Set 13 | gizo
# Processing Record 3 of Set 13 | khangarh
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | tekeli
# Processing Record 6 of Set 13 | shediac
# Processing Record 7 of Set 13 | rumford
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | inirida
# Processing Record 10 of Set 13 | estacion coahuila
# Processing Record 11 of Set 13 | parana
# Processing Record 12 of Set 13 | bama
# Processing Record 13 of Set 13 | taybad
# Processing Record 14 of Set 13 | mayumba
# Processing Record 15 of Set 13 | point pleasant
# Processing Record 16 of Set 13 | vardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 561

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Belmonte -15.8631  -38.8828     72.28        90          92        1.88
# 1   Udachnyy  66.4167  112.4000     -8.50        98         100        2.95
# 2   Thompson  55.7435  -97.8558     24.96       100         100        0.00
# 3  Tuatapere -46.1333  167.6833     58.60        52          94        7.76
# 4   Cherskiy  68.7500  161.3000    -38.42       100          32        1.30
# 5     Atuona  -9.8000 -139.0333     78.51        72          36       17.40
# 6      Bluff -46.6000  168.3333     60.80        59          85        5.53
# 7   Hermanus -34.4187   19.2345     61.81        71           2        8.14
# 8    Salalah  17.0151   54.0924     78.89        47          20        2.30
# 9      Muhos  64.8080   25.9931     10.18        96         100        3.74
#
#   Country Weather Description
# 0      BR     overcast clouds
# 1      RU     overcast clouds
# 2      CA          light snow
# 3      NZ     overcast clouds
# 4      RU    scattered clouds
# 5      PF    scattered clouds
# 6      NZ     overcast clouds
# 7      ZA           clear sky
# 8      OM          few clouds
# 9      FI     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Belmonte      BR -15.8631  -38.8828     72.28        90          92
# 1   Udachnyy      RU  66.4167  112.4000     -8.50        98         100
# 2   Thompson      CA  55.7435  -97.8558     24.96       100         100
# 3  Tuatapere      NZ -46.1333  167.6833     58.60        52          94
# 4   Cherskiy      RU  68.7500  161.3000    -38.42       100          32
# 5     Atuona      PF  -9.8000 -139.0333     78.51        72          36
# 6      Bluff      NZ -46.6000  168.3333     60.80        59          85
# 7   Hermanus      ZA -34.4187   19.2345     61.81        71           2
# 8    Salalah      OM  17.0151   54.0924     78.89        47          20
# 9      Muhos      FI  64.8080   25.9931     10.18        96         100
#
#    Wind Speed Weather Description
# 0        1.88     overcast clouds
# 1        2.95     overcast clouds
# 2        0.00          light snow
# 3        7.76     overcast clouds
# 4        1.30    scattered clouds
# 5       17.40    scattered clouds
# 6        5.53     overcast clouds
# 7        8.14           clear sky
# 8        2.30          few clouds
# 9        3.74     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df .dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
